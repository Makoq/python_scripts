# %%
from pyquery import PyQuery as py

doc=py(url="https://freegisdata.rtwilson.com/")
h4=doc('.container ul')
for ul in h4:
    print(ul.text)
    
    print('------')
# Out:
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
#
#
# ------
# ...

# %%
import requests
import re
from bs4 import BeautifulSoup

astr=[]

con=requests.get('https://freegisdata.rtwilson.com/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='container')
for ul in container[1].find_all('ul'):
    for li in ul:
        for a in li:
            if(a=='\n' or a=='.'):
                continue
            else:
                print(type(a))
                if(type(a)):
# for it in astr:
#     if(type(it)==)
#     print(type(it))
            

# print(container[1])
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-195-4f7836cca0ee> in <module>()
#      15             else:
#      16                 print(type(a))
# ---> 17                 if(a.tag):
#      18                     print(a.tag)
#      19 # for it in astr:
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
# --> 737                     self.__class__.__name__, attr))
#     738
#     739     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'tag'

# %%
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['Portal']
col=db['dataItem']


astr=[]
a=[]
# i=0
con=requests.get('https://freegisdata.rtwilson.com/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='container')
for a in container[1].find_all('a'):
    if(a.string==None):
        continue
#     print(a.string)
#     print(a.attrs['href'])
    t=[]
    if(a.string=='here'):
        continue
    t.append(a.string)
    t.append(a.attrs['href'])
    astr.append(t)
l=[]
for a in container[1].find_all('ul'):
    for li in a:
#         print(type(li))
        if(hasattr(li,'text')):
            l.append(li.text)
# print(len(astr),len(l))

print(l)
# for i in range(len(astr)-1,-1,-1):
#     col.insert_one({
#     "name":astr[i][0],
#     "description":l[i],
#     "detail":astr[i][1],
#     "author":"Internet",
#     "keywords":["online data"],
#     "classifications":["online data"],
#     "displays":[""],
#     "createTime":datetime.datetime.now(),
#     "lastModifyTime":datetime.datetime.now(),
#     "shareCount":1,
#     "viewCount":1,
#     "thumbsUpCount":0,
#     "comments":[],
# })
# Out:
# ['Natural Earth - Vector: Includes coastline,\nland, oceans, islands, rivers, lakes, glaciated areas and bathymetry. Available at multiple levels of detail. A version of this data is also available in the Wagner VII projection, which has good equal area properties, here.', 'Natural Earth - Raster: Includes various raster images, intended\nfor use as backgrounds for other data, for example hypsometric tints, satellite derived land cover,\nshaded relief etc.', 'Global Map: A set of consistent GIS layers covering the whole globe at 1km resolution including: transportation, elevation, drainage, vegetation, administrative boundaries, land cover, land use and population centres. Produced by the International Steering Committee on Global Mapping.', 'DIVA-GIS Country Data: A collection of data collected from a number of the sources below - includes administrative areas, inland water, roads and railways, elevation, land cover, population and climate. Probably the easiest place to get a simple
# ...

# %%
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['Portal']
col=db['dataItem']
 
i=0 
st=[]


# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>

con=requests.get('https://freegisdata.rtwilson.com/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='container')
for a in container[1].find_all('h4'):
    print(a.text)    
#     for li in a:
# #         print(type(li))
#         if(hasattr(li,'text')):
#             print(li.text)
#             print('----')
#             i=i+1
# print(i)
# Out:
# General
# Land and Ocean Boundaries
# Elevation
# Weather and Climate
# Hydrology
# Snow/Ice
# Natural Disasters
# Land Cover
# Ecology
# Mineral Resources/Oil and Gas
# General
# Administrative Boundaries
# Environmental Boundaries
# Land Use
# Lakes, Oceans and other Water Sources
# Wars, Conflict and Crime
# Population
# Buildings, Roads and Points of Interest
# Transport and Communications
# Gazetteers (place/feature names)
# Miscellaneous
# Afghanistan
# Antarctica
# Arctic
# Argentina
# Australia
# Austria
# Belgium
# Belize
# Bolivia
# Brazil
# Canada
# Central America
# Chile
# China
# Cyprus
# Denmark
# East Timor
# Finland
# France
# Germany
# Greece
# India
# Iceland
# Ireland
# Italy
# Japan
# Kenya
# Mexico
# Namibia
# Nepal
# The Netherlands
# New Zealand
# Norway
# Papa New Guinea
# Peru
# Philippines
# Portugal
# Puerto Rico
# Romania
# Russia
# Slovenia
# Spain
# South Africa
# Switzerland
# United Kingdom (UK)
# United Arab Emirates
# United States of America (USA)

# %%
from pymongo import MongoClient
import datetime
portal=MongoClient('222.192.7.75',27017)
db=portal['Portal']
col=db['dataItem']
col.insert_one({
    "name":"a.string",
    "description":"a.string",
    "detail":"a.string",
    "author":"Internet",
    "keywords":[],
    "classifications":["online data"],
    "displays":[""],
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":1,
    "viewCount":1,
    "thumbsUpCount":0,
    "comments":[],
})

# %%
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['Portal']
col=db['dataItem']
  
strs=[]

# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>

 
con=requests.get('https://freegisdata.rtwilson.com/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='container')
for ul in container[1].find_all('ul'):
    for li in ul:
        name=[]
        href=[]
        it=[]
        if(hasattr(li,'text')):
#             print(li.text)
            it.append(li.text)
        if(hasattr(li,'find_all')):
            for a in li.find_all('a'):
#                 print(a.attrs['href'])
#                 print(a.string)
                it.append(a.attrs['href'])
                it.append(a.string)
            strs.append(it)
#             print('--')
# print(len(strs))
# desxription href name


# print(strs)

for item in range(8,-1,-1):
    if(len(strs[item])<3):
        continue
    col.insert_one({
    "name":strs[item][2],
    "description":strs[item][0],
    "reference":strs[item][1],
    "author":"NJGIS",
    "keywords":["general physical geography"],
    "classifications":["5cc05ae37a419164e821234a","5cc04be67a419164e8212319"],
     "displays":['data:image/png;base64,...',
                 'data:image/png;base64,...'],
 
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":200,
    "viewCount":250,
    "thumbsUpCount":100,
    "comments":[],
})

# %%
from pymongo import MongoClient
import datetime
portal=MongoClient('222.192.7.75',27017)
db=portal['Portal']
col=db['categories']
col.insert_one({
    "name":"a.string",
    "description":"a.string",
    "detail":"a.string",
    "author":"Internet",
    "keywords":[],
    "classifications":["online data"],
    "displays":[""],
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":1,
    "viewCount":1,
    "thumbsUpCount":0b
    "comments":[],
})

# %%
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['data_scrapy_test']
col=db['freegisdata']
  
strs=[]

# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>

data_it={
    "name":'',
    "type":'option1',
    "description":'',
    "detail":'',
    "author":'NJGIS',
    "reference":'',
    "keywords":[],
    "classifications":[],
    "displays":['data:image/png;base64,...',
                 'data:image/png;base64,...'],
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":200,
    "viewCount":250,
    "thumbsUpCount":100,
    "contributers":["Robin Wilson"],
    "meta":[],
    "comments":[]
    
}

i=0

con=requests.get('https://freegisdata.rtwilson.com/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='container')
for ul in container[1].find_all('ul'):
    for li in ul.find_all('li'):
        data_it['description']=li.text #description       
        for a in li.find_all('a'):
            data_it['reference']=a.attrs['href'] #reference
            data_it['name']=a.text               #name
#             print(a.attrs['href'],a.text) #reference,name
            break;
    
        data_it['classifications'].append('5cc05ae37a419164e821234a')
        data_it['classifications'].append('5cc04be67a419164e8212319')
        data_it['keywords'].append('general physical geography')
#         print(data_it)
#         col.insert_one(data_it)
        strs.append(data_it)
        data_it['classifications']=[]
        data_it['classifications']=[]
        data_it['keywords']=[]
    break;
# print(data_it)

for s in range(len(strs)):
    col.insert_one(s)
    print("x")
# print(strs)

print('over')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ee8e122b91be> in <module>()
#      63
#      64 for s in range(len(strs)):
# ---> 65     col.insert_one(s)
#      66     print("x")
#      67 # print(strs)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     682         .. versionadded:: 3.0
#     683         """
# --> 684         common.validate_is_document_type("document", document)
#     685         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     686             document["_id"] = ObjectId()
#
# ~\Anaconda3\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     451                         "bson.raw_bson.RawBSONDocument, or "
#     452                         "a type that inherits from "
# ...

# %%
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['data_scrapy_test']
col=db['freegisdata']

item=[]
it=[]
con=requests.get('https://freegisdata.rtwilson.com/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='container')
for ul in container[1].find_all('ul'):
    for li in ul.find_all('li'):
        data_it['description']=li.text #description
        
#         print(li.text+'--') #detail
        
        for a in li.find_all('a'):
            data_it['reference']=a.attrs['href'] #reference
            data_it['name']=a.text               #name
#             print(a.attrs['href'],a.text) #reference,name
            break;
        
        data_it['classifications'].append('5cc05ae37a419164e821234a')
        data_it['classifications'].append('5cc04be67a419164e8212319')
        data_it['keywords'].append('general physical geography')
         
    break;

# %%
# scrapy  https://neo.sci.gsfc.nasa.gov/dataset_index.php#atmosphere
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['data_scrapy_test']
col=db['NASA_Neo']

 
data=[]


con=requests.get('https://neo.sci.gsfc.nasa.gov/dataset_index.php#atmosphere').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='dataset-display')
# print(container)

for dataset in container[4].find_all(class_='dataset'):
    itor=[]
    itor.append(dataset.p.a.strong.text) #name
    itor.append('https://neo.sci.gsfc.nasa.gov/'+dataset.a.attrs['href']) #url
    data.append(itor)
    print(dataset.p.a.strong.text)
    print('https://neo.sci.gsfc.nasa.gov/'+dataset.a.attrs['href'])

for e in data:
     col.insert_one({
    "name":e[0],
    "type":'option1',
    "description":"NASA ocean dataset",
    "reference":e[1],
    "author":"NJGIS",
         
        #
    "detail":'Sea surface temperatures influence weather, including hurricanes, as well as plant and animal life in the ocean.',
        #
     "keywords":["NASA","Ocean"],
         #
    "classifications":["5cb83fd0ea3cba3224b6e24e","5cc054e37a419164e8212329"],
         #
     "displays":["data:image/png;base64,..."],
 
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":200,
    "viewCount":250,
    "thumbsUpCount":100,
    "comments":[],
})
print(len(data))
# Out:
# Average Sea Surface Temperature (AVHRR, 1985-97)
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=AVHRR_CLIM_M
# Bathymetry
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=GEBCO_BATHY
# Blue Marble: Next Generation
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=BlueMarbleNG-TB
# Chlorophyll Concentration
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=MY1DMM_CHLORA
# Global Temperature Anomaly
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=GISS_TA_M
# Sea Ice and Snow Extent, Northern Hemisphere
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=SCSIE_W
# Sea Ice Concentration and Snow Extent, Global
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=NISE_D
# Sea Surface Salinity (2011-15)
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=AQUARIUS_SSS_M
# Sea Surface Temperature (AVHRR, 1981-2006)
# https://neo.sci.gsfc.nasa.gov//view.php?datasetId=AVHRR_SST_M
# Sea Surface Temperature (MWOI, 1998+)
# ...

# %%
#scrap https://globalmaps.github.io/
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['data_scrapy_test']
col=db['globalmaps.github']


data=[]
it=[]

former=''

con=requests.get('https://globalmaps.github.io/').text
soup=BeautifulSoup(con,'lxml')
container=soup.find_all(class_='box1')

for li in container[0].ul.find_all('li'):
    if li.a==former:
        continue
    else:
#         if li.a.attrs['href'].startswhith('.')：
#             it.append(li.a.text);
#             it.append('https://globalmaps.github.io/'+li.a.attrs['href'])
#         else：
        it=[]
        it.append(li.a.text);
        it.append(li.a.attrs['href'])
        data.append(it)
        former=li.a
#         print(li.a.attrs['href'])
# print(it)
for it in range(7,len(data)):
    data[it][1]='https://globalmaps.github.io/'+data[it][1]
    
for e in data:
     col.insert_one({
    "name":e[0],
    "type":'option1',
    "description":"Global Map data archives",
    "reference":e[1],
    "author":"NJGIS",
         
        #
    "detail":'Unfortunately, the International Steering Committee for Global Mapping (ISCGM) resolved to transfer Global Map data to the Geospatial Information Section in the UN.But that doesn’t mean the data is gone forever. That’s because their archives have been uploaded to the Global Map Github data archives site.Global Map still packs some serious punch with their free GIS data. For example, global land cover and percent tree cover are the two pivotal datasets here. But that’s not all. It has cultural and natural vector datasets in here too.Since the move, registration is no longer required. Despite the lack of updates, ISCGM free GIS data is still a source that many of us can enjoy in our maps.Download global land cover and tree prevent by selecting map tiles.Boundaries, drainage, transportation, population centers, elevation, land cover, land use and vegetation.',
        #
     "keywords":["ISCGM","Global Map"],
         #
    "classifications":["5cc04be67a419164e8212319","5cc05aa97a419164e8212344","5cc04b987a419164e8212316"],
         #
     "displays":["data:image/png;base64,..."],
 
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":200,
    "viewCount":250,
    "thumbsUpCount":100,
    "comments":[],
})

# %%
#scrap  https://hub.arcgis.com/search?collection=Dataset
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime

portal=MongoClient('222.192.7.75',27017)
db=portal['data_scrapy_test']
col=db['arcgis_hub']


data=[]
it=[]

former=''
url="https://hub.arcgis.com/search?collection=Dataset"
con=requests.get(url).text
soup=BeautifulSoup(con,'lxml')
alldiv=soup.find_all('div',class_='ember-view')

print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
#scrap  https://hub.arcgis.com/search?collection=Dataset
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime
import json

portal=MongoClient('222.192.7.75',27017)
db=portal['data_scrapy_test']
col=db['arcgisHub']

url='https://opendata.arcgis.com/api/v3/datasets'

it=[]
happy=[]
params={
    "fields[datasets]":"name,modified,modifiedProvenance,searchDescription,recordCount,source,extent,owner,thumbnailUrl,type,url,xFrameOptions,contentSecurityPolicy,siteUrl,tags,collection,size,initiativeCategories,slug",
    "agg[fields]":"downloadable,hasApi,sector,region,source,tags,type",
    "filter[collection]":"any(Dataset)",
    "filter[openData]":"true",
    "page[size]":"10",
    "page[number]":1
}


for i in range(451,501):#截取页码
    print(i)
    params['page[number]']=i+1
    r=requests.get(url,params)
    response=json.loads(r.text)
    data=response['data']
#     print(data)
    for el in data:
        it=[]
        if 'url' in el['attributes']:
            it.append(el.get("attributes").get("name"))#name
            it.append(el['attributes']['tags'])#keywords
            it.append(el['attributes']['searchDescription'])#description
            it.append("https://hub.arcgis.com/datasets/"+el['attributes']['url'])#url

            happy.append(it)
        else:
            print(i,"no url")
            continue
        

for e in happy:
     col.insert_one({
    "name":e[0],
    "type":'option1',
    "description":e[2],
    "reference":e[3],
    "author":"NJGIS",
         
        #detail字段写死
    "detail":'<p>In 2017, Esri Open Data is the hidden gold mine of free GIS data. For example, it now lets you explore over 67,310 open data sets from 4,092 organizations worldwide. For this reason, we have it at the top of our list of free GIS data.In some cases, you’ll have to sift through piles of data and merge your downloads into one. Despite the effort, this is arguably your best chance to find exactly what you’re looking for.In any case, the search is convenient with a map preview of the extent and table. Alternatively, you can search by topic or location and download data in multiple GIS formats. Ultimately, there is nothing more thorough for GIS data than Esri Open Data.</p>',
        #
     "keywords":e[1],
         #分类的id
    "classifications":["5cc05aa97a419164e8212344","5cc057ff7a419164e8212338","5cc058147a419164e8212339","5cc054bd7a419164e8212323"],
         #
     "displays":["data:image/png;base64,..."],
 
    "createTime":datetime.datetime.now(),
    "lastModifyTime":datetime.datetime.now(),
    "shareCount":200,
    "viewCount":250,
    "thumbsUpCount":100,
    "comments":[],
})

print('over')
# Out:
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 457 no url
# 458
# 458 no url
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# over

# %%
import requests
import re
from bs4 import BeautifulSoup
from pymongo import MongoClient
import datetime
import json

# portal=MongoClient('localhost',27017)
# db=portal['data_items']
# col_test=db['test']

# col_dataItems_01=db['dataItems_01']
# col_category=db["category_back"]
# count=col_test.find({ 'OGMS_category':{'$ne':[]}}).count()
# print(count)  
data_items=MongoClient("localhost",27017)
db=data_items['data_items']
col_test=db['test']

col_dataItems_01=db['dataItems_01']
col_category=db["category_back_01"]

def all_cate_id():
    all_id=[]
    for cateid in col_category.find({}):        
        all_id.append(cateid['_id'])
    return all_id   
def only(d_id,cate_id):
    
    ca=col_category.find_one({"_id":"ObjectId(\""+cate_id+"\")"})
    if d_id in ca["dataItem"]:
        return False
    
    else:
        return True
    
def inser_category(data_id,category_d):
    if(only(data_id,category_d)):
        col_category.update({"_id":"ObjectId(\""+category_id+"\")" },{ "$push":{"dataItem":data_id}})
        print(category_d )#打印操作项
    
    
if __name__=="__main__":
    categoryid=all_cate_id()
 
    for d in col_dataItems_01.find({}):
        for data_cate_id in d['OGMS_category']:
            if(data_cate_id in categoryid):
                inser_category(d['_id'],data_cate_id)

# %%
a="qwqw"
print(a[1:-1])
# Out:
# wq
